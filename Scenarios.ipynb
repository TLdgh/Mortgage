# %%
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go
from Mortgage import Amortization
from Mortgage import plotResult

# %% [markdown]
# # Instruction

# %%
#Calculate Payment amount if n is known and a fixed interest rate:
result=Amortization(Balance=[30000], Rate=[[1, 0.03/12]])
result.CalcPayment(result.N) #use N=25 default value
# Out:
#     Month  IntRate   Payment  Interests  Principal    Balance
# 0       0    0.000     0.000      0.000      0.000  30000.000
# 1       1    0.002  1239.389     75.000   1164.389  28835.611
# 2       2    0.002  1239.389     72.089   1167.300  27668.310
# 3       3    0.002  1239.389     69.171   1170.219  26498.091
# 4       4    0.002  1239.389     66.245   1173.144  25324.947
# 5       5    0.002  1239.389     63.312   1176.077  24148.870
# 6       6    0.002  1239.389     60.372   1179.017  22969.853
# 7       7    0.002  1239.389     57.425   1181.965  21787.888
# 8       8    0.002  1239.389     54.470   1184.920  20602.968
# 9       9    0.002  1239.389     51.507   1187.882  19415.086
# 10     10    0.002  1239.389     48.538   1190.852  18224.234
# 11     11    0.002  1239.389     45.561   1193.829  17030.405
# 12     12    0.002  1239.389     42.576   1196.813  15833.592
# 13     13    0.002  1239.389     39.584   1199.806  14633.786
# ...

# %%
#Calculate Payment amount if variable interest rate:
result=Amortization(Balance=[30000], Rate=[[1, 0.05], [10, 0.03], [15, 0.02], [20, 0.01]], N=28)
result.CalcPayment(result.N) #use specified N value
# Out:
#     Month  IntRate   Payment  Interests  Principal    Balance
# 0       0     0.00     0.000      0.000      0.000  30000.000
# 1       1     0.05  2013.676   1500.000    513.676  29486.324
# 2       2     0.05  2013.676   1474.316    539.360  28946.964
# 3       3     0.05  2013.676   1447.348    566.328  28380.637
# 4       4     0.05  2013.676   1419.032    594.644  27785.993
# 5       5     0.05  2013.676   1389.300    624.376  27161.616
# 6       6     0.05  2013.676   1358.081    655.595  26506.021
# 7       7     0.05  2013.676   1325.301    688.375  25817.646
# 8       8     0.05  2013.676   1290.882    722.794  25094.853
# 9       9     0.05  2013.676   1254.743    758.933  24335.920
# 10     10     0.03  1698.985    730.078    968.907  23367.012
# 11     11     0.03  1698.985    701.010    997.975  22369.038
# 12     12     0.03  1698.985    671.071   1027.914  21341.124
# 13     13     0.03  1698.985    640.234   1058.751  20282.372
# ...

# %%
#Estimate time to payout gien a fixed rate and equal payment 
result=Amortization(Balance=[30000], Rate=[[1, 0.03]], Payment=[1964.03]*26)
result.CalcTime()
# Out:
#     Month  IntRate   Payment  Interests  Principal    Balance
# 0       0     0.00     0.000      0.000      0.000  30000.000
# 1       1     0.03  1964.030    900.000   1064.030  28935.970
# 2       2     0.03  1964.030    868.079   1095.951  27840.019
# 3       3     0.03  1964.030    835.201   1128.829  26711.190
# 4       4     0.03  1964.030    801.336   1162.694  25548.495
# 5       5     0.03  1964.030    766.455   1197.575  24350.920
# 6       6     0.03  1964.030    730.528   1233.502  23117.418
# 7       7     0.03  1964.030    693.523   1270.507  21846.910
# 8       8     0.03  1964.030    655.407   1308.623  20538.288
# 9       9     0.03  1964.030    616.149   1347.881  19190.406
# 10     10     0.03  1964.030    575.712   1388.318  17802.088
# 11     11     0.03  1964.030    534.063   1429.967  16372.121
# 12     12     0.03  1964.030    491.164   1472.866  14899.255
# 13     13     0.03  1964.030    446.978   1517.052  13382.202
# ...

# %%
#Estimate time to payout gien a fixed rate and variable payment 
result=Amortization(Balance=[30000], Rate=[[1, 0.03]], Payment=[1964.03]*12+[1000]*26)
result.CalcTime()
# Out:
#     Month  IntRate   Payment  Interests  Principal    Balance
# 0       0     0.00     0.000      0.000      0.000  30000.000
# 1       1     0.03  1964.030    900.000   1064.030  28935.970
# 2       2     0.03  1964.030    868.079   1095.951  27840.019
# 3       3     0.03  1964.030    835.201   1128.829  26711.190
# 4       4     0.03  1964.030    801.336   1162.694  25548.495
# 5       5     0.03  1964.030    766.455   1197.575  24350.920
# 6       6     0.03  1964.030    730.528   1233.502  23117.418
# 7       7     0.03  1964.030    693.523   1270.507  21846.910
# 8       8     0.03  1964.030    655.407   1308.623  20538.288
# 9       9     0.03  1964.030    616.149   1347.881  19190.406
# 10     10     0.03  1964.030    575.712   1388.318  17802.088
# 11     11     0.03  1964.030    534.063   1429.967  16372.121
# 12     12     0.03  1964.030    491.164   1472.866  14899.255
# 13     13     0.03  1000.000    446.978    553.022  14346.232
# ...

# %%
#Estimate time to payout gien a variable rate and equal payment 
result=Amortization(Balance=[30000], Rate=[[1, 0.01], [13, 0.006], [22, 0.002]], Payment=[963]*30)
result.CalcTime()
# Out:
#     Month  IntRate  Payment  Interests  Principal    Balance
# 0       0    0.000        0      0.000      0.000  30000.000
# 1       1    0.010      963    300.000    663.000  29337.000
# 2       2    0.010      963    293.370    669.630  28667.370
# 3       3    0.010      963    286.674    676.326  27991.044
# 4       4    0.010      963    279.910    683.090  27307.954
# 5       5    0.010      963    273.080    689.920  26618.034
# 6       6    0.010      963    266.180    696.820  25921.214
# 7       7    0.010      963    259.212    703.788  25217.426
# 8       8    0.010      963    252.174    710.826  24506.600
# 9       9    0.010      963    245.066    717.934  23788.666
# 10     10    0.010      963    237.887    725.113  23063.553
# 11     11    0.010      963    230.636    732.364  22331.189
# 12     12    0.010      963    223.312    739.688  21591.501
# 13     13    0.006      963    129.549    833.451  20758.050
# ...

# %%
#Estimate time need to payout gien a variable rate and variable payment 
result=Amortization(Balance=[30000], Rate=[[1, 0.01], [13, 0.006]], Payment=[664.03]*12+[10000]+[1200]*12)
result.CalcTime()
# Out:
#     Month  IntRate   Payment  Interests  Principal    Balance
# 0       0    0.000      0.00      0.000      0.000  30000.000
# 1       1    0.010    664.03    300.000    364.030  29635.970
# 2       2    0.010    664.03    296.360    367.670  29268.300
# 3       3    0.010    664.03    292.683    371.347  28896.953
# 4       4    0.010    664.03    288.970    375.060  28521.892
# 5       5    0.010    664.03    285.219    378.811  28143.081
# 6       6    0.010    664.03    281.431    382.599  27760.482
# 7       7    0.010    664.03    277.605    386.425  27374.057
# 8       8    0.010    664.03    273.741    390.289  26983.767
# 9       9    0.010    664.03    269.838    394.192  26589.575
# 10     10    0.010    664.03    265.896    398.134  26191.441
# 11     11    0.010    664.03    261.914    402.116  25789.325
# 12     12    0.010    664.03    257.893    406.137  25383.188
# 13     13    0.006  10000.00    152.299   9847.701  15535.488
# ...

# %% [markdown]
# # Scenario Analysis
#
# #### Suppose given the interest rate and duration of the loan, the original monthly payment is first calculated, and then the time to payout is re-estimated when the interest rate changes in the 37th month and an extra payment equal to 8% of the outstanding balance converted to monthly.

# %%
#利率不变
result1=Amortization(Balance=[200000], Rate=[[1, 0.0509/12]], N=25*12)
result1.CalcPayment(N=result1.N)

#利率3年后大幅上涨，没有提前还款，压力巨大
newPay=[1179.691]*36+[3159.245]*36+[1939.687]*228
result2=Amortization(Balance=[200000], Rate=[[1, 0.0509/12], [37, 0.2/12], [73, 0.11/12]], Payment=newPay)
result2.CalcTime()

#利率3年后大幅上涨，后期提前还款，压力仍然巨大
newPay=[1179.691]*36+[3159.245]*36+[1939.687*2]*200
result3=Amortization(Balance=[200000], Rate=[[1, 0.0509/12], [37, 0.2/12], [73, 0.11/12]], Payment=newPay)
result3.CalcTime()

#利率3年后大幅上涨，提前还款并且保持
newPay=[1179.691]*6+[1179.691*2]*160
result4=Amortization(Balance=[200000], Rate=[[1, 0.0509/12], [37, 0.2/12], [73, 0.11/12]], Payment=newPay, BalancePctPay=0.08/12)
result4.CalcTime()

#利率3年后大幅上涨，提前还款并且支撑5年，后期还原
newPay=[1179.691]*6+[1179.691*2]*60+[1179.691]*200
result5=Amortization(Balance=[200000], Rate=[[1, 0.0509/12], [37, 0.2/12], [73, 0.11/12]], Payment=newPay, BalancePctPay=0.08/12)
result5.CalcTime()

plotResult({"df1":result1.data, "df2":result2.data, "df3":result3.data, "df4":result4.data, "df5":result5.data})

#结论
#4 和 5利息差不多，但5后期还原，所以5最好
# Out:
#      Month  IntRate   Payment  Interests  Principal     Balance
# 0        0    0.000     0.000      0.000      0.000  200000.000
# 1        1    0.004  1179.691    848.333    331.358  199668.642
# 2        2    0.004  1179.691    846.928    332.763  199335.879
# 3        3    0.004  1179.691    845.516    334.175  199001.704
# 4        4    0.004  1179.691    844.099    335.592  198666.111
# ..     ...      ...       ...        ...        ...         ...
# 296    296    0.004  1179.691     24.704   1154.987    4669.148
# 297    297    0.004  1179.691     19.805   1159.886    3509.262
# 298    298    0.004  1179.691     14.885   1164.806    2344.455
# 299    299    0.004  1179.691      9.944   1169.747    1174.709
# 300    300    0.004  1179.691      4.983   1174.709       0.000
#
# [301 rows x 6 columns]
#      Month  IntRate   Payment  Interests  Principal     Balance
# 0        0    0.000     0.000      0.000      0.000  200000.000
# ...

# %%
#利率小幅下降，3年内提前还款，后期还原
newPay=[1179.691]*6+[1179.691*2]*36+[1179.691]*100
result6=Amortization(Balance=[200000], Rate=[[1, 0.0509/12], [37, 0.04/12]], Payment=newPay, BalancePctPay=0.08/12)
result6.CalcTime()

#利率小幅下降，3年内提前还款，后期还原，没有 Balance Percentage Pay
newPay=[1179.691]*6+[1179.691*2]*36+[1179.691]*200
result7=Amortization(Balance=[200000], Rate=[[1, 0.0509/12], [37, 0.04/12]], Payment=newPay)
result7.CalcTime()

#利率小幅下降，3年内提前还款并且保持
newPay=[1179.691]*6+[1179.691*2]*100
result8=Amortization(Balance=[200000], Rate=[[1, 0.0509/12], [37, 0.04/12]], Payment=newPay, BalancePctPay=0.08/12)
result8.CalcTime()

#利率小幅下降，3年内提前还款并且保持，没有 Balance Percentage Pay
newPay=[1179.691]*6+[1179.691*2]*110
result9=Amortization(Balance=[200000], Rate=[[1, 0.0509/12], [37, 0.04/12]], Payment=newPay)
result9.CalcTime()

plotResult({"df6":result6.data, "df7":result7.data, "df8":result8.data, "df9":result9.data})

#结论：
#6 和 8 利息差不多，同时6后期还原，所以6最好
# Out:
#      Month  IntRate   Payment  Interests  Principal     Balance
# 0        0    0.000     0.000      0.000      0.000  200000.000
# 1        1    0.004  2513.024    848.333   1664.691  198335.309
# 2        2    0.004  2501.926    841.272   1660.654  196674.655
# 3        3    0.004  2490.855    834.228   1656.627  195018.028
# 4        4    0.004  2479.811    827.201   1652.610  193365.418
# ..     ...      ...       ...        ...        ...         ...
# 108    108    0.003  1214.053     17.181   1196.872    3957.437
# 109    109    0.003  1206.074     13.191   1192.882    2764.554
# 110    110    0.003  1198.121      9.215   1188.906    1575.648
# 111    111    0.003  1190.195      5.252   1184.943     390.705
# 112    112    0.003   392.007      1.302    390.705       0.000
#
# [113 rows x 6 columns]
#      Month  IntRate   Payment  Interests  Principal     Balance
# 0        0    0.000     0.000      0.000      0.000  200000.000
# ...

# %% [markdown]
# ## Variable Rate Vs. Fixed Rate

# %%
#Calculate Payment amount if n is known and a fixed interest rate:
result=Amortization(Balance=[200000], Rate=[[1, 0.0489/12]], N=25*12)
result.CalcPayment(result.N) #use N=25 default value
# Out:
#      Month  IntRate   Payment  Interests  Principal     Balance
# 0        0    0.000     0.000      0.000      0.000  200000.000
# 1        1    0.004  1156.398    815.000    341.398  199658.602
# 2        2    0.004  1156.398    813.609    342.789  199315.812
# 3        3    0.004  1156.398    812.212    344.186  198971.626
# 4        4    0.004  1156.398    810.809    345.589  198626.037
# ..     ...      ...       ...        ...        ...         ...
# 296    296    0.004  1156.398     23.276   1133.122    4578.851
# 297    297    0.004  1156.398     18.659   1137.739    3441.112
# 298    298    0.004  1156.398     14.023   1142.376    2298.736
# 299    299    0.004  1156.398      9.367   1147.031    1151.705
# 300    300    0.004  1156.398      4.693   1151.705       0.000
#
# [301 rows x 6 columns]

# %%
#浮动利率1年后降到4.5%并维持，固定3年后改成4.5%

#Double + 8%
newPay=[1258.213]*6+[1258.213*2]*200
result1=Amortization(Balance=[200000], Rate=[[1, 0.0575/12],[2, 0.055/12],[5, 0.0525/12],[7, 0.05/12],
                                             [10, 0.0475/12], [13, 0.045/12]], Payment=newPay, BalancePctPay=0.08/12)
result1.CalcTime()

newPay=[1156.398]*6+[1156.398*2]*300
result2=Amortization(Balance=[200000], Rate=[[1, 0.0489/12], [37, 0.045/12]], Payment=newPay, BalancePctPay=0.08/12)
result2.CalcTime()

plotResult({"df1":result1.data, "df2":result2.data})

#结论：浮动利息2万9，固定3万2，相差3000
# Out:
#     Month  IntRate   Payment  Interests  Principal     Balance
# 0       0    0.000     0.000      0.000      0.000  200000.000
# 1       1    0.005  2591.546    958.333   1633.213  198366.787
# 2       2    0.005  2580.658    909.181   1671.477  196695.310
# 3       3    0.005  2569.515    901.520   1667.995  195027.315
# 4       4    0.005  2558.395    893.875   1664.520  193362.795
# ..    ...      ...       ...        ...        ...         ...
# 71     71    0.004  2588.122     40.329   2547.793    8206.597
# 72     72    0.004  2571.137     30.775   2540.362    5666.235
# 73     73    0.004  2554.201     21.248   2532.953    3133.283
# 74     74    0.004  2537.315     11.750   2525.565     607.718
# 75     75    0.004   609.997      2.279    607.718       0.000
#
# [76 rows x 6 columns]
#     Month  IntRate   Payment  Interests  Principal     Balance
# 0       0    0.000     0.000      0.000      0.000  200000.000
# ...

# %%
#Double for 3 years + 8% 
newPay=[1258.213]*6+[1258.213*2]*36+[1258.213]*200
result1=Amortization(Balance=[200000], Rate=[[1, 0.0575/12],[2, 0.055/12],[5, 0.0525/12],[7, 0.05/12],
                                             [10, 0.0475/12], [13, 0.045/12]], Payment=newPay, BalancePctPay=0.08/12)
result1.CalcTime()

newPay=[1156.398]*6+[1156.398*2]*36+[1156.398]*200
result2=Amortization(Balance=[200000], Rate=[[1, 0.0489/12], [37, 0.045/12]], Payment=newPay, BalancePctPay=0.08/12)
result2.CalcTime()

plotResult({"df1":result1.data, "df2":result2.data})

#结论：浮动利息3万4，固定3万8，相差4000
# Out:
#      Month  IntRate   Payment  Interests  Principal     Balance
# 0        0    0.000     0.000      0.000      0.000  200000.000
# 1        1    0.005  2591.546    958.333   1633.213  198366.787
# 2        2    0.005  2580.658    909.181   1671.477  196695.310
# 3        3    0.005  2569.515    901.520   1667.995  195027.315
# 4        4    0.005  2558.395    893.875   1664.520  193362.795
# ..     ...      ...       ...        ...        ...         ...
# 100    100    0.004  1298.013     22.388   1275.626    4694.448
# 101    101    0.004  1289.509     17.604   1271.905    3422.543
# 102    102    0.004  1281.030     12.835   1268.195    2154.348
# 103    103    0.004  1272.575      8.079   1264.497     889.851
# 104    104    0.004   893.188      3.337    889.851       0.000
#
# [105 rows x 6 columns]
#      Month  IntRate   Payment  Interests  Principal     Balance
# 0        0    0.000     0.000      0.000      0.000  200000.000
# ...

# %%
#No Double + 8%
newPay=[1258.213]*6+[1258.213]*200
result1=Amortization(Balance=[200000], Rate=[[1, 0.0575/12],[2, 0.055/12],[5, 0.0525/12],[7, 0.05/12],
                                             [10, 0.0475/12], [13, 0.045/12]], Payment=newPay, BalancePctPay=0.08/12)
result1.CalcTime()

newPay=[1156.398]*6+[1156.398]*200
result2=Amortization(Balance=[200000], Rate=[[1, 0.0489/12], [37, 0.045/12]], Payment=newPay, BalancePctPay=0.08/12)
result2.CalcTime()

plotResult({"df1":result1.data, "df2":result2.data})

#结论：浮动利息4万8，固定5万3，相差5000
# Out:
#      Month  IntRate   Payment  Interests  Principal     Balance
# 0        0    0.000     0.000      0.000      0.000  200000.000
# 1        1    0.005  2591.546    958.333   1633.213  198366.787
# 2        2    0.005  2580.658    909.181   1671.477  196695.310
# 3        3    0.005  2569.515    901.520   1667.995  195027.315
# 4        4    0.005  2558.395    893.875   1664.520  193362.795
# ..     ...      ...       ...        ...        ...         ...
# 128    128    0.004  1293.006     19.571   1273.435    3945.548
# 129    129    0.004  1284.517     14.796   1269.721    2675.828
# 130    130    0.004  1276.052     10.034   1266.017    1409.810
# 131    131    0.004  1267.612      5.287   1262.325     147.485
# 132    132    0.004   148.038      0.553    147.485       0.000
#
# [133 rows x 6 columns]
#      Month  IntRate   Payment  Interests  Principal     Balance
# 0        0    0.000     0.000      0.000      0.000  200000.000
# ...

# %%
#Double forever, no 8% 
newPay=[1258.213]*6+[1258.213*2]*200
result1=Amortization(Balance=[200000], Rate=[[1, 0.0575/12],[2, 0.055/12],[5, 0.0525/12],[7, 0.05/12],
                                             [10, 0.0475/12], [13, 0.045/12]], Payment=newPay)
result1.CalcTime()

newPay=[1156.398]*6+[1156.398*2]*200
result2=Amortization(Balance=[200000], Rate=[[1, 0.0489/12], [37, 0.045/12]], Payment=newPay)
result2.CalcTime()

plotResult({"df1":result1.data, "df2":result2.data})

#结论：浮动利息4万3，固定4万9，相差6000
# Out:
#      Month  IntRate   Payment  Interests  Principal     Balance
# 0        0    0.000     0.000      0.000      0.000  200000.000
# 1        1    0.005  1258.213    958.333    299.880  199700.120
# 2        2    0.005  1258.213    915.292    342.921  199357.200
# 3        3    0.005  1258.213    913.720    344.493  199012.707
# 4        4    0.005  1258.213    912.142    346.071  198666.636
# ..     ...      ...       ...        ...        ...         ...
# 96      96    0.004  2516.426     42.521   2473.905    8865.127
# 97      97    0.004  2516.426     33.244   2483.182    6381.946
# 98      98    0.004  2516.426     23.932   2492.494    3889.452
# 99      99    0.004  2516.426     14.585   2501.841    1387.611
# 100    100    0.004  1392.815      5.204   1387.611       0.000
#
# [101 rows x 6 columns]
#      Month  IntRate   Payment  Interests  Principal     Balance
# 0        0    0.000     0.000      0.000      0.000  200000.000
# ...

# %%
#Double for 3 years, no 8% 
newPay=[1258.213]*6+[1258.213*2]*36+[1258.213]*200
result1=Amortization(Balance=[200000], Rate=[[1, 0.0575/12],[2, 0.055/12],[5, 0.0525/12],[7, 0.05/12],
                                             [10, 0.0475/12], [13, 0.045/12]], Payment=newPay)
result1.CalcTime()

newPay=[1156.398]*6+[1156.398*2]*36+[1156.398]*200
result2=Amortization(Balance=[200000], Rate=[[1, 0.0489/12], [37, 0.045/12]], Payment=newPay)
result2.CalcTime()

plotResult({"df1":result1.data, "df2":result2.data})

#结论：浮动利息6万3，固定7万6，相差1万3
# Out:
#      Month  IntRate   Payment  Interests  Principal     Balance
# 0        0    0.000     0.000      0.000      0.000  200000.000
# 1        1    0.005  1258.213    958.333    299.880  199700.120
# 2        2    0.005  1258.213    915.292    342.921  199357.200
# 3        3    0.005  1258.213    913.720    344.493  199012.707
# 4        4    0.005  1258.213    912.142    346.071  198666.636
# ..     ...      ...       ...        ...        ...         ...
# 170    170    0.004  1258.213     18.735   1239.478    3756.420
# 171    171    0.004  1258.213     14.087   1244.126    2512.294
# 172    172    0.004  1258.213      9.421   1248.792    1263.502
# 173    173    0.004  1258.213      4.738   1253.475      10.027
# 174    174    0.004    10.065      0.038     10.027       0.000
#
# [175 rows x 6 columns]
#      Month  IntRate   Payment  Interests  Principal     Balance
# 0        0    0.000     0.000      0.000      0.000  200000.000
# ...

# %%
#No Double, no 8% 
newPay=[1258.213]*6+[1258.213]*300
result1=Amortization(Balance=[200000], Rate=[[1, 0.0575/12],[2, 0.055/12],[5, 0.0525/12],[7, 0.05/12],
                                             [10, 0.0475/12], [13, 0.045/12]], Payment=newPay)
result1.CalcTime()

newPay=[1156.398]*6+[1156.398]*300
result2=Amortization(Balance=[200000], Rate=[[1, 0.0489/12], [37, 0.045/12]], Payment=newPay)
result2.CalcTime()

plotResult({"df1":result1.data, "df2":result2.data})

#结论：浮动利息10万8，固定12万8，相差2万
# Out:
#      Month  IntRate   Payment  Interests  Principal     Balance
# 0        0    0.000     0.000      0.000      0.000  200000.000
# 1        1    0.005  1258.213    958.333    299.880  199700.120
# 2        2    0.005  1258.213    915.292    342.921  199357.200
# 3        3    0.005  1258.213    913.720    344.493  199012.707
# 4        4    0.005  1258.213    912.142    346.071  198666.636
# ..     ...      ...       ...        ...        ...         ...
# 241    241    0.004  1258.213     22.289   1235.924    4707.756
# 242    242    0.004  1258.213     17.654   1240.559    3467.197
# 243    243    0.004  1258.213     13.002   1245.211    2221.986
# 244    244    0.004  1258.213      8.332   1249.881     972.106
# 245    245    0.004   975.751      3.645    972.106       0.000
#
# [246 rows x 6 columns]
#      Month  IntRate   Payment  Interests  Principal     Balance
# 0        0    0.000     0.000      0.000      0.000  200000.000
# ...
